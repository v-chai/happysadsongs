# %% [markdown]
# # IMPORTS

# %%
import re
import pandas as pd
import numpy as np
import requests 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import unicodedata
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.preprocessing import OneHotEncoder
from gensim.models import Word2Vec
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
from tensorflow.keras import Sequential
from tensorflow.keras import layers
import gensim.downloader as api
import matplotlib.pyplot as plt  
from sklearn.datasets import make_classification
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## IMPORT COMPLETE  TEXT- SENTIIMENT DATABASE

# %%
text_df = pd.read_csv(r'/Users/magvera/code/v-chai/happysadsongs/raw_data/emotion_dataset.csv')
text_df
# Out:
#        Unnamed: 0                                               text  \
# 0               0                            i didnt feel humiliated
# 1               1  i can go from feeling so hopeless to so damned...
# 2               2   im grabbing a minute to post i feel greedy wrong
# 3               3                               i am feeling grouchy
# 4               4  ive been feeling a little burdened lately wasn...
# ...           ...                                                ...
# 41122        5570  There's doing stupid things when you're young....
# 41123        5571  So now disabled people don’t have rights . Y...
# 41124        5572  It is. I bet chantex and all the other 'quit s...
# 41125        5573  [NAME] was half-blood but it wasn't a smart id...
# 41126        5574  What are you talking about? Anything bad that ...
#
#       word_label             source
# 0            sad        HuggingFace
# 1            sad        HuggingFace
# 2          angry        HuggingFace
# 3          angry        HuggingFace
# 4            sad        HuggingFace
# ...          ...                ...
# 41122      angry  Google_GoEmotions
# 41123      angry  Google_GoEmotions
# 41124      angry  Google_GoEmotions
# 41125      angry  Google_GoEmotions
# 41126      angry  Google_GoEmotions
#
# [41127 rows x 4 columns]

# %% [markdown]
# ## IMPORT COMPLETE LABELED LYRICS DATABASE

# %%
lyrics_df = pd.read_csv(r'/Users/magvera/code/v-chai/happysadsongs/raw_data/fragments_songs.csv')
lyrics_df=lyrics_df[:6]
lyrics_df
# Out:
#              Artist               Song  \
# 0            Queen   Don't stop me now
# 1            eminem       the way I am
# 2           rihanna         unfaithful
# 3      taylor swift        white horse
# 4         metallica          st. Anger
# 5  pharrel williams              happy
#
#                                               lyrics  label
# 0  Tonight I'm gonna have myself a real good time...  happy
# 1  My tank is on empty, no patience is in me\nAnd...  angry
# 2  I don't wanna do this anymore\nI don't wanna b...    sad
# 3  That I'm not a princess, this ain't a fairy ta...    sad
# 4  Fuck it all and no regrets\nI hit the lights o...  angry
# 5  It might seem crazy what I'm about to say\nSun...  happy

# %% [markdown]
# # TEXT - SENTIMENT

# %% [markdown]
# ## Cleaning Database

# %%
# Consider reducing this list further
stop_words = set(stopwords.words('english')) - {
    'into', 'against', 'myself', 'doing', 'own', 'above', 'our', 'now', 'up',
    'down', 'been', 'not', 'no', 'would', 'should', 'again', 'won', 'if',
    'only', 'yours', 'your', 'you', 'ours', 'here', 'there', 'below', 'before'
}


def get_training_data():
    # ADD CODE
    pass

def get_lyrics_data():
    # ADD CODE
    pass

def clean(text):
    # lowercase
    new_text = text.lower()

    # remove twitter handles
    new_text = re.sub(r"@\w+", '', new_text)

    # remove urls
    new_text = re.sub(r'http:\S+', '', new_text)
    new_text = re.sub(r'https:\S+', '', new_text)

    # remove punctuation
    for punctuation in string.punctuation:
        new_text = new_text.replace(punctuation, '')

    # remove numbers
    new_text = ''.join(word for word in new_text if not word.isdigit())

    return new_text


def remove_stopwords(text):
    word_list = [
        word for word in word_tokenize(text) if not word in stop_words
    ]
    return ' '.join(word_list)


def lemma_text(text):
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(word) for word in word_tokenize(text)]
    return ' '.join(lemmatized)


# Possibly remove single letter words
def clean_length(text):
    return [word for word in text if len(word) > 2]

# %%
text_df['clean_text']=text_df['text'].apply(clean)
text_df
# Out:
#        Unnamed: 0                                               text  \
# 0               0                            i didnt feel humiliated
# 1               1  i can go from feeling so hopeless to so damned...
# 2               2   im grabbing a minute to post i feel greedy wrong
# 3               3                               i am feeling grouchy
# 4               4  ive been feeling a little burdened lately wasn...
# ...           ...                                                ...
# 41122        5570  There's doing stupid things when you're young....
# 41123        5571  So now disabled people don’t have rights . Y...
# 41124        5572  It is. I bet chantex and all the other 'quit s...
# 41125        5573  [NAME] was half-blood but it wasn't a smart id...
# 41126        5574  What are you talking about? Anything bad that ...
#
#       word_label             source  \
# 0            sad        HuggingFace
# 1            sad        HuggingFace
# 2          angry        HuggingFace
# 3          angry        HuggingFace
# 4            sad        HuggingFace
# ...          ...                ...
# 41122      angry  Google_GoEmotions
# 41123      angry  Google_GoEmotions
# 41124      angry  Google_GoEmotions
# 41125      angry  Google_GoEmotions
# 41126      angry  Google_GoEmotions
#
#                                               clean_text
# 0                                i didnt feel humiliated
# 1      i can go from feeling so hopeless to so damned...
# 2       im grabbing a minute to post i feel greedy wrong
# 3                                   i am feeling grouchy
# 4      ive been feeling a little burdened lately wasn...
# ...                                                  ...
# 41122  theres doing stupid things when youre young th...
# 41123  so now disabled people don⊙t have rights  yo...
# 41124  it is i bet chantex and all the other quit smo...
# 41125  name was halfblood but it wasnt a smart idea t...
# 41126  what are you talking about anything bad that h...
#
# [41127 rows x 5 columns]

# %%
text_df['clean_text']=text_df['clean_text'].apply(remove_stopwords)
text_df
# Out:
#        Unnamed: 0                                               text  \
# 0               0                            i didnt feel humiliated
# 1               1  i can go from feeling so hopeless to so damned...
# 2               2   im grabbing a minute to post i feel greedy wrong
# 3               3                               i am feeling grouchy
# 4               4  ive been feeling a little burdened lately wasn...
# ...           ...                                                ...
# 41122        5570  There's doing stupid things when you're young....
# 41123        5571  So now disabled people don’t have rights . Y...
# 41124        5572  It is. I bet chantex and all the other 'quit s...
# 41125        5573  [NAME] was half-blood but it wasn't a smart id...
# 41126        5574  What are you talking about? Anything bad that ...
#
#       word_label             source  \
# 0            sad        HuggingFace
# 1            sad        HuggingFace
# 2          angry        HuggingFace
# 3          angry        HuggingFace
# 4            sad        HuggingFace
# ...          ...                ...
# 41122      angry  Google_GoEmotions
# 41123      angry  Google_GoEmotions
# 41124      angry  Google_GoEmotions
# 41125      angry  Google_GoEmotions
# 41126      angry  Google_GoEmotions
#
#                                               clean_text
# 0                                  didnt feel humiliated
# 1      go feeling hopeless damned hopeful around some...
# 2              im grabbing minute post feel greedy wrong
# 3                                        feeling grouchy
# 4      ive been feeling little burdened lately wasnt ...
# ...                                                  ...
# 41122  theres doing stupid things youre young theres ...
# 41123   now disabled people don⊙t rights you get worse
# 41124  bet chantex quit smoking companies hope book d...
# 41125    name halfblood wasnt smart idea bring up father
# 41126  you talking anything bad happened name fault o...
#
# [41127 rows x 5 columns]

# %%
text_df['clean_text']=text_df['clean_text'].apply(lemma_text)
text_df
# Out:
#        Unnamed: 0                                               text  \
# 0               0                            i didnt feel humiliated
# 1               1  i can go from feeling so hopeless to so damned...
# 2               2   im grabbing a minute to post i feel greedy wrong
# 3               3                               i am feeling grouchy
# 4               4  ive been feeling a little burdened lately wasn...
# ...           ...                                                ...
# 41122        5570  There's doing stupid things when you're young....
# 41123        5571  So now disabled people don’t have rights . Y...
# 41124        5572  It is. I bet chantex and all the other 'quit s...
# 41125        5573  [NAME] was half-blood but it wasn't a smart id...
# 41126        5574  What are you talking about? Anything bad that ...
#
#       word_label             source  \
# 0            sad        HuggingFace
# 1            sad        HuggingFace
# 2          angry        HuggingFace
# 3          angry        HuggingFace
# 4            sad        HuggingFace
# ...          ...                ...
# 41122      angry  Google_GoEmotions
# 41123      angry  Google_GoEmotions
# 41124      angry  Google_GoEmotions
# 41125      angry  Google_GoEmotions
# 41126      angry  Google_GoEmotions
#
#                                               clean_text
# 0                                  didnt feel humiliated
# 1      go feeling hopeless damned hopeful around some...
# 2              im grabbing minute post feel greedy wrong
# 3                                        feeling grouchy
# 4      ive been feeling little burdened lately wasnt ...
# ...                                                  ...
# 41122  there doing stupid thing youre young there doi...
# 41123    now disabled people don⊙t right you get worse
# 41124  bet chantex quit smoking company hope book doe...
# 41125    name halfblood wasnt smart idea bring up father
# 41126  you talking anything bad happened name fault o...
#
# [41127 rows x 5 columns]

# %% [markdown]
# ## ENCODING SENTIMENTS

# %%
text_df.word_label.unique()
# Out:
# array(['sad', 'angry', 'happy'], dtype=object)

# %%
#ONE HOT ENCODING THE WORD_LABEL column (into sad, angry and happy)

ohe = OneHotEncoder(sparse = False)
ohe.fit(text_df[['word_label']])

feature_list =ohe.categories_[0].tolist()
text_df[feature_list]=ohe.transform(text_df[['word_label']])
text_df.drop(columns=['word_label'], inplace=True)

text_df.head()
# Out:
#    Unnamed: 0                                               text       source  \
# 0           0                            i didnt feel humiliated  HuggingFace
# 1           1  i can go from feeling so hopeless to so damned...  HuggingFace
# 2           2   im grabbing a minute to post i feel greedy wrong  HuggingFace
# 3           3                               i am feeling grouchy  HuggingFace
# 4           4  ive been feeling a little burdened lately wasn...  HuggingFace
#
#                                           clean_text  angry  happy  sad
# 0                              didnt feel humiliated    0.0    0.0  1.0
# 1  go feeling hopeless damned hopeful around some...    0.0    0.0  1.0
# 2          im grabbing minute post feel greedy wrong    1.0    0.0  0.0
# 3                                    feeling grouchy    1.0    0.0  0.0
# 4  ive been feeling little burdened lately wasnt ...    0.0    0.0  1.0

# %%
## For clean text
df_clean_text=text_df['clean_text'].tolist()
clean_text=[]
for sentence in df_clean_text:
    word_token = word_tokenize(sentence)
    clean_text.append(word_token)

# %% [markdown]
# ## TRAIN TEST SPLIT

# %%
y = text_df[['angry', 'happy', 'sad']]
X= clean_text

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state = 0) # Holdout

# %% [markdown]
# ## TRANSFER LEARNING

# %%
def init_model():
    model = Sequential()
    model.add(layers.Masking())
    model.add(layers.LSTM(20, activation='tanh'))
    model.add(layers.Dense(15, activation='relu'))
    model.add(layers.Dense(3, activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer='rmsprop',
                  metrics=[['accuracy','Precision','Recall']])
    
    return model

model = init_model()
# Out:
# 2021-09-08 14:11:19.453137: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Global Vector Twitter 200
word2vec_transfer = api.load('glove-twitter-200')

# %%
def embed_sentence_with_TF(word2vec, sentence):
    embedded_sentence = []
    for word in sentence:
        if word in word2vec:
            embedded_sentence.append(word2vec[word])
        
    return np.array(embedded_sentence)


def embedding(word2vec, sentences):
    embed = []
    
    for sentence in sentences:
        embedded_sentence = embed_sentence_with_TF(word2vec, sentence)
        embed.append(embedded_sentence)
        
    return embed

X_train_embed_2 = embedding(word2vec_transfer, X_train)
X_test_embed_2 = embedding(word2vec_transfer, X_test)

# %%
# Pad the training and test embedded sentences
X_train_pad_2 = pad_sequences(X_train_embed_2, dtype='float32', padding='post', maxlen=500)
X_test_pad_2 = pad_sequences(X_test_embed_2, dtype='float32', padding='post', maxlen=500)

# %%
es = EarlyStopping(patience=2, restore_best_weights=True)

model = init_model()

model.fit(X_train_pad_2, y_train, 
          batch_size = 64,
          epochs=20,
          validation_split=0.3,
          
          callbacks=[es]
         )
# Out:
# Epoch 1/20
# 315/315 [==============================] - 168s 507ms/step - loss: 0.8160 - accuracy: 0.6312 - precision: 0.7264 - recall: 0.4665 - val_loss: 0.6998 - val_accuracy: 0.7071 - val_precision: 0.7467 - val_recall: 0.6395
# Epoch 2/20
# 315/315 [==============================] - 158s 501ms/step - loss: 0.6414 - accuracy: 0.7341 - precision: 0.7718 - recall: 0.6801 - val_loss: 0.6259 - val_accuracy: 0.7407 - val_precision: 0.7783 - val_recall: 0.6905
# Epoch 3/20
# 315/315 [==============================] - 200s 635ms/step - loss: 0.5727 - accuracy: 0.7695 - precision: 0.7992 - recall: 0.7227 - val_loss: 0.5912 - val_accuracy: 0.7624 - val_precision: 0.7949 - val_recall: 0.7189
# Epoch 4/20
# 315/315 [==============================] - 176s 558ms/step - loss: 0.5306 - accuracy: 0.7855 - precision: 0.8164 - recall: 0.7464 - val_loss: 0.5692 - val_accuracy: 0.7701 - val_precision: 0.7998 - val_recall: 0.7353
# Epoch 5/20
# 315/315 [==============================] - 153s 486ms/step - loss: 0.4964 - accuracy: 0.8014 - precision: 0.8277 - recall: 0.7672 - val_loss: 0.5817 - val_accuracy: 0.7664 - val_precision: 0.7928 - val_recall: 0.7345
# Epoch 6/20
# 315/315 [==============================] - 144s 458ms/step - loss: 0.4693 - accuracy: 0.8113 - precision: 0.8392 - recall: 0.7810 - val_loss: 0.5739 - val_accuracy: 0.7734 - val_precision: 0.7992 - val_recall: 0.7488

# %%
res = model.evaluate(X_test_pad_2, y_test, verbose=0)

print(f'The accuracy evaluated on the test set is of {res[1]*100:.3f}%')
print(f'The precision evaluated on the test set is of {res[2]*100:.3f}%')
print(f'The recall evaluated on the test set is of {res[3]*100:.3f}%')
# Out:
# The accuracy evaluated on the test set is of 77.462%
# The precision evaluated on the test set is of 80.441%
# The recall evaluated on the test set is of 73.831%

# %% [markdown]
# # LYRICS

# %% [markdown]
# ## CLEANING LYRICS DATASET

# %%
lyrics_df['clean_lyrics']=lyrics_df['lyrics'].apply(clean)
lyrics_df['clean_lyrics']=lyrics_df['clean_lyrics'].apply(remove_stopwords)
lyrics_df['clean_lyrics']=lyrics_df['clean_lyrics'].apply(lemma_text)
lyrics_df
# Out:
#              Artist               Song  \
# 0            Queen   Don't stop me now
# 1            eminem       the way I am
# 2           rihanna         unfaithful
# 3      taylor swift        white horse
# 4         metallica          st. Anger
# 5  pharrel williams              happy
#
#                                               lyrics  label  \
# 0  Tonight I'm gonna have myself a real good time...  happy
# 1  My tank is on empty, no patience is in me\nAnd...  angry
# 2  I don't wanna do this anymore\nI don't wanna b...    sad
# 3  That I'm not a princess, this ain't a fairy ta...    sad
# 4  Fuck it all and no regrets\nI hit the lights o...  angry
# 5  It might seem crazy what I'm about to say\nSun...  happy
#
#                                         clean_lyrics
# 0  tonight im gon na myself real good time feel a...
# 1  tank empty no patience if you offend im liftin...
# 2  dont wan na anymore dont wan na reason every t...
# 3  im not princess aint fairy tale im not one you...
# 4  fuck no regret hit light dark set need voice l...
# 5  might seem crazy im say sunshine shes here you...

# %% [markdown]
# ## ENCODING SENTIMENTS

# %%
lyrics_df.label.unique()
# Out:
# array(['happy', 'angry', 'sad'], dtype=object)

# %%
#ONE HOT ENCODING THE WORD_LABEL column (into sad, angry and happy)

ohe = OneHotEncoder(sparse = False)
ohe.fit(lyrics_df[['label']])

feature_list =ohe.categories_[0].tolist()
lyrics_df[feature_list]=ohe.transform(lyrics_df[['label']])
lyrics_df.drop(columns=['label'], inplace=True)

lyrics_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/tb/bzc4x2g16g30zw04zffzkkw40000gn/T/ipykernel_54499/1743608633.py in <module>
#       2
#       3 ohe = OneHotEncoder(sparse = False)
# ----> 4 ohe.fit(lyrics_df[['label']])
#       5
#       6 feature_list =ohe.categories_[0].tolist()
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['label'], dtype='object')] are in the [columns]"

# %%
## For clean text
df_clean_lyrics=lyrics_df['clean_lyrics'].tolist()
clean_lyrics=[]
for sentence in df_clean_lyrics:
    word_token = word_tokenize(sentence)
    clean_lyrics.append(word_token)

# %% [markdown]
# ## SPLITTING DATASET

# %%
y = lyrics_df[['angry', 'happy', 'sad']]
X = clean_lyrics

# %% [markdown]
# ## EMBEDDING X AND Y

# %%
def embed_sentence_with_TF(word2vec, sentence):
    embedded_sentence = []
    for word in sentence:
        if word in word2vec:
            embedded_sentence.append(word2vec[word])
        
    return np.array(embedded_sentence)


def embedding(word2vec, sentences):
    embed = []
    
    for sentence in sentences:
        embedded_sentence = embed_sentence_with_TF(word2vec, sentence)
        embed.append(embedded_sentence)
        
    return embed

X_embed = embedding(word2vec_transfer, X)
X_pad = pad_sequences(X_embed, dtype='float32', padding='post', maxlen=500)

# %% [markdown]
# ## EVALUATING THE MODEL ON LYRICS

# %%
res = model.evaluate(X_pad, y, verbose=0)

# %%
print(f'The accuracy evaluated on the lyrics set is of {res[1]*100:.3f}%')
print(f'The precision evaluated on the lyrics set is of {res[2]*100:.3f}%')
print(f'The recall evaluated on the lyrics set is of {res[3]*100:.3f}%')
# Out:
# The accuracy evaluated on the lyrics set is of 50.000%
# The precision evaluated on the lyrics set is of 50.000%
# The recall evaluated on the lyrics set is of 50.000%
